# %% [markdown]
# implementation of ANN for IRIS dataset

# %% [markdown]
# #### Importing essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

# %% [markdown]
# #### Loading data from CSV

# %%
folder='C:/Users/kdehn/OneDrive - stevens.edu/___Data/CSV_files/'
df = pd.read_csv(folder+'iris.csv')

# %%
df.head(10)
# Out:
#   Species  SepalLength  SepalWidth  PetalLength  PetalWidth
# 0  Setosa           50          33           14           2
# 1  Setosa           46          34           14           3
# 2  Setosa           46          36           10           2
# 3  Setosa           51          33           17           5
# 4  Setosa           55          35           13           2
# 5  Setosa           48          31           16           2
# 6  Setosa           52          34           14           2
# 7  Setosa           49          36           14           1
# 8  Setosa           44          32           13           2
# 9  Setosa           50          35           16           6

# %% [markdown]
# #### Splitting data into attributes & target

# %%
attr = df.drop(columns=[ 'Species'])
target = df['Species']

# %%
attr.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0           50          33           14           2
# 1           46          34           14           3
# 2           46          36           10           2
# 3           51          33           17           5
# 4           55          35           13           2

# %%
target=pd.get_dummies(target,prefix='ouput')
target.head()
# Out:
#    ouput_Setosa  ouput_Versicolor  ouput_Virginica
# 0          True             False            False
# 1          True             False            False
# 2          True             False            False
# 3          True             False            False
# 4          True             False            False

# %% [markdown]
# #### Normalizing data

# %%
scaler = StandardScaler()
attr = pd.DataFrame(scaler.fit_transform(attr), columns=attr.columns)
attr.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0    -1.021849    0.558611    -1.340227   -1.315444
# 1    -1.506521    0.788808    -1.340227   -1.183812
# 2    -1.506521    1.249201    -1.567576   -1.315444
# 3    -0.900681    0.558611    -1.169714   -0.920548
# 4    -0.416010    1.019004    -1.397064   -1.315444

# %% [markdown]
# #### Splitting data into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(attr, target,random_state=82, test_size=0.3)
print(X_train.shape)
print(y_train.shape)
# Out:
# (105, 4)
# (105, 3)

# %% [markdown]
# ### Artificial Neural Network

# %%
model = MLPClassifier(hidden_layer_sizes=(4,), max_iter=10000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# #### Loss Curve

# %%
sns.lineplot(x=range(len(model.loss_curve_)), y=model.loss_curve_)
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# C:\Users\kdehn\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kdehn\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Evaluation

# %%
# Accuracy Score

accuracy = metrics.accuracy_score(y_pred, y_test)
print("Accuracy: {} ({:.2%})".format(accuracy, accuracy))
# Out:
# Accuracy: 0.9777777777777777 (97.78%)
